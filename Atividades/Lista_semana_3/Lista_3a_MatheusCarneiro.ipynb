# %% [markdown]
# <div class="alert alert-block alert-info">
# <center>ESTATÍSTICA APLICADA</center>
# <center>LISTA 1a</center>
# <center>ALUNO: Matheus Carneiro da Cunha</center>
# </div>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <div class="alert alert-block alert-info">
# Resposta da questão 1)
# </div>

# %% [markdown]
# ## 1)
# as listas são mutáveis, ordenadas, heterogêneas, indexada por posição e delimitada por colchetes [ ],
# os dicionarios tambem são mutaveis e heterogêneos, mas não são ordenados e são indexadas e delimitada por chaves { },
# os arrays numpy são de um pacote de extensão do Python e são matrizes multi-dimensioais,
# e as series pandas tambem de uma biblioteca do Python são matrizes unidimensionais rotuladas capazes de armazenar dados de qualquer tipo.

# %% [markdown]
# <div class="alert alert-block alert-info">
# Resposta da questão 2)
# </div>

# %%
ser = pd.Series(np.random.randint(1, 10, 35))
b=ser.values
c=b.reshape((7,5))
df2 = pd.DataFrame(data=c)
df2 = pd.DataFrame(data=df)
df2
# Out:
#    0  1  2  3  4
# 0  1  8  1  1  1
# 1  9  6  3  8  8
# 2  2  8  9  4  1
# 3  3  6  9  6  7
# 4  7  1  1  2  9
# 5  8  2  4  3  9
# 6  9  9  1  4  6

# %% [markdown]
# <div class="alert alert-block alert-info">
# Resposta da questão 3)
# </div>

# %%
quest3 = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv', usecols=['crim','medv'])
quest3
# Out:
#         crim  medv
# 0    0.00632  24.0
# 1    0.02731  21.6
# 2    0.02729  34.7
# 3    0.03237  33.4
# 4    0.06905  36.2
# ..       ...   ...
# 501  0.06263  22.4
# 502  0.04527  20.6
# 503  0.06076  23.9
# 504  0.10959  22.0
# 505  0.04741  11.9
#
# [506 rows x 2 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# Resposta da questão 4)
# </div>

# %%
df4 = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
df4.rename(columns={'Type' : 'CarType','Min.Price': 'Min_Price','Max.Price': 'Max_Price','MPG.city': 'MPG_city','MPG.highway': 'MPG_highway','Rev.per.mile': 'Rev_per_mile','Man.trans.avail': 'Man_trans_avail','Fuel.tank.capacity': 'Fuel_tank_capacity','Turn.circle': 'Turn_circle','Rear.seat.room': 'Rear_seat_room','Luggage.room': 'Luggage_room'}, inplace = True)
df4
# Out:
#    Manufacturer    Model  CarType  Min_Price  Price  Max_Price  MPG_city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92          NaN      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG_highway             AirBags DriveTrain  ... Passengers  Length  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# Resposta da questão 5)
# </div>

# %%
df5 = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
df5.isnull()
# Out:
#     Manufacturer  Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 0          False  False  False      False  False      False     False
# 1           True  False  False      False  False      False     False
# 2          False  False  False      False  False      False     False
# 3          False  False  False       True  False      False     False
# 4          False  False  False       True  False       True     False
# ..           ...    ...    ...        ...    ...        ...       ...
# 88         False  False  False      False  False      False     False
# 89         False  False  False      False  False      False     False
# 90         False  False  False      False  False      False     False
# 91         False  False  False      False  False      False     False
# 92          True  False  False      False  False      False     False
#
#     MPG.highway  AirBags  DriveTrain  ...  Passengers  Length  Wheelbase  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# Resposta da questão 6)
# </div>

# %%
df6 = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
df6.isnull().sum()
# Out:
# Manufacturer           4
# Model                  1
# Type                   3
# Min.Price              7
# Price                  2
# Max.Price              5
# MPG.city               9
# MPG.highway            2
# AirBags                6
# DriveTrain             7
# Cylinders              5
# EngineSize             2
# Horsepower             7
# RPM                    3
# Rev.per.mile           6
# Man.trans.avail        5
# Fuel.tank.capacity     8
# Passengers             2
# Length                 4
# Wheelbase              1
# Width                  6
# Turn.circle            5
# Rear.seat.room         4
# Luggage.room          19
# Weight                 7
# Origin                 5
# Make                   3
# dtype: int64

# %% [markdown]
# ## 6)
# A coluna que tem mais é 'Luggage.room' com 19 valores ausentes.

# %% [markdown]
# <div class="alert alert-block alert-info">
# Resposta da questão 7)
# </div>

# %%
df7 = pd.DataFrame(np.arange(20).reshape(-1, 5), columns=list('abcde'))
df7 = pd.DataFrame(df7["a"])
df7
# Out:
#     a
# 0   0
# 1   5
# 2  10
# 3  15

# %% [markdown]
# <div class="alert alert-block alert-info">
# Resposta da questão 8)
# </div>

# %% [markdown]
# ## a)

# %%
df8 = pd.DataFrame(np.arange(20).reshape(-1, 5), columns=list('abcde'))
df8.reindex(columns=['c','b','a','d','e'])
# Out:
#     c   b   a   d   e
# 0   2   1   0   3   4
# 1   7   6   5   8   9
# 2  12  11  10  13  14
# 3  17  16  15  18  19

# %% [markdown]
# ## b)

# %% [markdown]
# ## c)

# %%
df8 = pd.DataFrame(np.arange(20).reshape(-1, 5), columns=list('abcde'))
df8.reindex(columns=['e','d','c','b','a'])
# Out:
#     e   d   c   b   a
# 0   4   3   2   1   0
# 1   9   8   7   6   5
# 2  14  13  12  11  10
# 3  19  18  17  16  15

# %% [markdown]
# <div class="alert alert-block alert-info">
# Resposta da questão 9)
# </div>

# %%
df9 = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
df9.iloc[:10,:10]
# Out:
#   Manufacturer       Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura     Integra    Small       12.9   15.9       18.8      25.0
# 1          NaN      Legend  Midsize       29.2   33.9       38.7      18.0
# 2         Audi          90  Compact       25.9   29.1       32.3      20.0
# 3         Audi         100  Midsize        NaN   37.7       44.6      19.0
# 4          BMW        535i  Midsize        NaN   30.0        NaN      22.0
# 5        Buick     Century  Midsize       14.2   15.7       17.3      22.0
# 6        Buick     LeSabre    Large       19.9   20.8        NaN      19.0
# 7        Buick  Roadmaster    Large       22.6   23.7       24.9      16.0
# 8        Buick     Riviera  Midsize       26.3   26.3       26.3      19.0
# 9     Cadillac     DeVille    Large       33.0   34.7       36.3      16.0
#
#    MPG.highway             AirBags DriveTrain
# 0         31.0                None      Front
# 1         25.0  Driver & Passenger      Front
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# Resposta da questão 10)
# </div>

# %%
df10 = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv', usecols=['Manufacturer','Model','Type'])

df10.loc[0::20]
# Out:
#    Manufacturer    Model     Type
# 0         Acura  Integra    Small
# 20     Chrysler  LeBaron  Compact
# 40        Honda  Prelude   Sporty
# 60      Mercury   Cougar  Midsize
# 80       Subaru   Loyale    Small

# %% [markdown]
# <div class="alert alert-block alert-info">
# Resposta da questão 11)
# </div>

# %%
df11 = pd.DataFrame(np.random.randint(10, 40, 60).reshape(-1, 4))
df11 = df11.loc[df11.sum(axis=1) > 100]
df11.tail(2)
# Out:
#      0   1   2   3
# 11  36  28  36  19
# 13  26  31  30  37

# %%
df11 = pd.DataFrame(np.random.randint(10, 40, 60).reshape(-1, 4))
df111 = df11.sum(axis=1)
df1111 = df111[df111 < 100]
df1111.tail(2).index
# Out:
# 12    75
# 14    92
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info">
# Resposta da questão 12)
# </div>

# %%
df12 = pd.DataFrame(np.arange(25).reshape(5, -1))
a, b = df12.iloc[1].copy(), df12.iloc[2].copy()
df12.iloc[1],df12.iloc[2] = b,a
df12
# Out:
#     0   1   2   3   4
# 0   0   1   2   3   4
# 1  10  11  12  13  14
# 2   5   6   7   8   9
# 3  15  16  17  18  19
# 4  20  21  22  23  24
